# %% [markdown]
# # FILE_INPUT_OUTPUT

# %%
file = open('demo.text','w')
file.write(''' Files
hshdbjmhjsdjgbjdsbjhjdjmjhnsddjmjsdjmjdsjmjsjmjsmdkjnds kjsdksdjksk
sdjmujhsd jshdn jsdjmnjsxjmnss jmjdsmxksjxnjjmsdx
smxjjsjxmcnjjsdmxcnjjsdmxjkjndjsxm
sdjsdxjmcn jsmdjxmnsmjxmcnskdjxmnskjxmcn
''')
file.close()

# %%
file1=open('loops.ipynb','r')
print(file1.read())
file1.close()
# Out:
# {
#  "cells": [
#   {
#    "cell_type": "code",
#    "execution_count": 2,
#    "metadata": {},
#    "outputs": [
#     {
#      "name": "stdin",
#      "output_type": "stream",
#      "text": [
#       "Please provide your Name: Simeon\n",
#       "Please provide your gender: Male\n",
#       "Please provide your age: 30\n",
#       "Please provide your marital status: Single\n"
#      ]
#     },
#     {
#      "name": "stdout",
#      "output_type": "stream",
#      "text": [
#       "congratulations Simeon you have been posted to Rivers\n"
#      ]
#     }
#    ],
#    "source": [
#     "import random\n",
#     "Name = input('Please provide your Name:')\n",
#     "gender = input('Please provide your gender:')\n",
#     "age  = int(input('Please provide your age:'))\n",
#     "marital_status = input('Please provide your marital status:')\n",
#     "state = ['Lagos','Edo','Rivers','Delta','Kano','Plateu']\n",
#     "if gender == 'Female' and marital_status == 'Married':\n",
# ...

# %%
file2=open('demo.text','a')
file2.write('\npython is fun, easy to use and understand')
file2.close()

# %%
file3=open('demo.text','r+')
print(file3.read())
file3.close()
# Out:
#  Files
# hshdbjmhjsdjgbjdsbjhjdjmjhnsddjmjsdjmjdsjmjsjmjsmdkjnds kjsdksdjksk
# sdjmujhsd jshdn jsdjmnjsxjmnss jmjdsmxksjxnjjmsdx
# smxjjsjxmcnjjsdmxcnjjsdmxjkjndjsxm
# sdjsdxjmcn jsmdjxmnsmjxmcnskdjxmnskjxmcn
#
# python is fun, easy to use and understand

# %%
file3=open('demo.text','r+')
print(file3.read())
file3.write('''\nBelow are the content in pythoen
1. sysntax
2. variables
3. data types
4. Iterable object
5. operators
6. control flow program
7. Ooops etc.........
''')
file3.close()
# Out:
#  Files
# hshdbjmhjsdjgbjdsbjhjdjmjhnsddjmjsdjmjdsjmjsjmjsmdkjnds kjsdksdjksk
# sdjmujhsd jshdn jsdjmnjsxjmnss jmjdsmxksjxnjjmsdx
# smxjjsjxmcnjjsdmxcnjjsdmxjkjndjsxm
# sdjsdxjmcn jsmdjxmnsmjxmcnskdjxmnskjxmcn
#
# python is fun, easy to use and understand

# %%
file4=open('guest_list.doc','w')
file4.write('''Guest_Name                                     Time of Arrival
Emmanuel                                         11:59 am
John                                             11:59am
Gabriel                                          11:59am
''')
file4.close()

# %%
file4=open('guest_list.doc','r+')
print(file4.read())
file4.close()
# Out:
# Guest_Name                                     Time of Arrival
# Emmanuel                                         11:59 am
# John                                             11:59am
# Gabriel                                          11:59am

# %% [markdown]
# # ERROR HANDLING

# %%
try:
    content = open('Computer Crime and its Impact.docx','r')
    con_split = content.split()
except FileNotFoundError:
    print('The file you are trying to read does not exist')
except:
    print('you have encountered one or more errors')
else:
    small =large=len(con_split[0])
    for i in range (0,len(con_split))
    word = len(len(con_split))
    if word <=small
